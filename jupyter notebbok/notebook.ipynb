# %% [markdown]
# Problem Statement
#
# Food Delivery services like Zomato and Swiggy need to show the accurate time it will take to deliver your order to keep transparency with their customers. These companies use Machine Learning algorithms to predict the food delivery time based on how much time the delivery partners took for the same distance in the past.
#
# To predict the food delivery time in real-time, we need to calculate the distance between the food preparation point and the point of food consumption. After finding the distance between the restaurant and the delivery locations, we need to find relationships between the time taken by delivery partners to deliver the food in the past for the same distance.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from math import radians, sin, cos, sqrt, atan2
import warnings
import folium
import datetime

# filter out warning messages
warnings.filterwarnings("ignore")

from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OrdinalEncoder,OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import KNNImputer

from sklearn.model_selection import train_test_split

# %% [markdown]
# 1.1 Reading dataset

# %%
df=pd.read_csv('finalTrain.csv')

# %%
df.head()
# Out:
#        ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0  0xcdcd      DEHRES17DEL01                 36.0                      4.2
# 1  0xd987      KOCRES16DEL01                 21.0                      4.7
# 2  0x2784     PUNERES13DEL03                 23.0                      4.7
# 3  0xc8b6     LUDHRES15DEL02                 34.0                      4.3
# 4  0xdb64      KNPRES14DEL02                 24.0                      4.7
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            30.327968             78.046106                   30.397968
# 1            10.003064             76.307589                   10.043064
# 2            18.562450             73.916619                   18.652450
# 3            30.899584             75.809346                   30.919584
# 4            26.463504             80.372929                   26.593504
#
#    Delivery_location_longitude  Order_Date Time_Orderd Time_Order_picked  \
# ...

# %% [markdown]
# 1.2  checkining data Shape,Columns,Null values and Info

# %%
df.shape
# Out:
# (45584, 20)

# %% [markdown]
# Data has 45584 rfecords of orders

# %%
df.columns
# Out:
# Index(['ID', 'Delivery_person_ID', 'Delivery_person_Age',
#        'Delivery_person_Ratings', 'Restaurant_latitude',
#        'Restaurant_longitude', 'Delivery_location_latitude',
#        'Delivery_location_longitude', 'Order_Date', 'Time_Orderd',
#        'Time_Order_picked', 'Weather_conditions', 'Road_traffic_density',
#        'Vehicle_condition', 'Type_of_order', 'Type_of_vehicle',
#        'multiple_deliveries', 'Festival', 'City', 'Time_taken (min)'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# ID                                0
# Delivery_person_ID                0
# Delivery_person_Age            1854
# Delivery_person_Ratings        1908
# Restaurant_latitude               0
# Restaurant_longitude              0
# Delivery_location_latitude        0
# Delivery_location_longitude       0
# Order_Date                        0
# Time_Orderd                    1731
# Time_Order_picked                 0
# Weather_conditions              616
# Road_traffic_density            601
# Vehicle_condition                 0
# Type_of_order                     0
# Type_of_vehicle                   0
# multiple_deliveries             993
# Festival                        228
# City                           1200
# Time_taken (min)                  0
# dtype: int64

# %% [markdown]
# data has missing values in severel columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45584 entries, 0 to 45583
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           45584 non-null  object
#  1   Delivery_person_ID           45584 non-null  object
#  2   Delivery_person_Age          43730 non-null  float64
#  3   Delivery_person_Ratings      43676 non-null  float64
#  4   Restaurant_latitude          45584 non-null  float64
#  5   Restaurant_longitude         45584 non-null  float64
#  6   Delivery_location_latitude   45584 non-null  float64
#  7   Delivery_location_longitude  45584 non-null  float64
#  8   Order_Date                   45584 non-null  object
#  9   Time_Orderd                  43853 non-null  object
#  10  Time_Order_picked            45584 non-null  object
#  11  Weather_conditions           44968 non-null  object
# ...

# %% [markdown]
# Order_Date,Time_orederd,TIme_Order_Picked columns missclassified as ibject datatype but it is Datetime data type

# %% [markdown]
# 1.2 Five Number Summary

# %%
df.describe()
# Out:
#        Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude  \
# count         43730.000000             43676.000000         45584.000000
# mean             29.566911                 4.633774            17.017948
# std               5.815064                 0.334744             8.185674
# min              15.000000                 1.000000           -30.905562
# 25%              25.000000                 4.500000            12.933284
# 50%              30.000000                 4.700000            18.551440
# 75%              35.000000                 4.900000            22.728163
# max              50.000000                 6.000000            30.914057
#
#        Restaurant_longitude  Delivery_location_latitude  \
# count          45584.000000                45584.000000
# mean              70.229684                   17.465480
# std               22.885575                    7.335562
# min              -88.366217                    0.010000
# ...

# %% [markdown]
# Delivery person are only in rangee of 15-50

# %% [markdown]
# 2.0 droping unnecessary coulmns

# %%
df.drop(['ID','Delivery_person_ID'],axis=1,inplace=True)

# %%
df
# Out:
#        Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude  \
# 0                     36.0                      4.2            30.327968
# 1                     21.0                      4.7            10.003064
# 2                     23.0                      4.7            18.562450
# 3                     34.0                      4.3            30.899584
# 4                     24.0                      4.7            26.463504
# ...                    ...                      ...                  ...
# 45579                 30.0                      4.8            26.902328
# 45580                 21.0                      4.6             0.000000
# 45581                 30.0                      4.9            13.022394
# 45582                 20.0                      4.7            11.001753
# 45583                 23.0                      4.9            23.351058
#
#        Restaurant_longitude  Delivery_location_latitude  \
# ...

# %% [markdown]
# 2.1 channging column data types

# %%
date_format = "%d-%m-%Y"
df['Order_Date'] = pd.to_datetime(df['Order_Date'],format=date_format)

# %%
df['year']= df['Order_Date'].dt.year
df['month']= df['Order_Date'].dt.month
df['day']= df['Order_Date'].dt.day

# %%
df.drop('Order_Date',axis=1,inplace=True)

# %% [markdown]
# 2.1.2formating time orderd

# %%
df['Time_Orderd'].unique()
# Out:
# array(['21:55', '14:55', '17:30', '09:20', '19:50', '20:25', '20:30',
#        '20:40', '21:15', '20:20', '22:30', '08:15', '19:30', '12:25',
#        '18:35', '20:35', '23:20', '21:20', '23:35', '22:35', '23:25',
#        '13:35', '21:35', '18:55', '14:15', '0.458333333', '09:45',
#        '08:40', '0.958333333', '17:25', nan, '19:45', '19:10', '10:55',
#        '21:40', '0.791666667', '16:45', '11:30', '15:10', '22:45',
#        '22:10', '20:45', '22:50', '17:55', '09:25', '20:15', '22:25',
#        '22:40', '23:50', '15:25', '10:20', '20:55', '10:40', '15:55',
#        '20:10', '12:10', '15:30', '10:35', '21:10', '20:50', '12:35',
#        '0.875', '23:40', '18:15', '18:20', '11:45', '12:45', '23:30',
#        '10:50', '21:25', '10:10', '17:50', '22:20', '12:40', '23:55',
#        '10:25', '08:45', '23:45', '19:55', '22:15', '23:10', '09:15',
#        '18:25', '18:45', '16:50', '1', '14:20', '10:15', '08:50', '0.375',
# ...

# %%
df.sample(5)
# Out:
#        Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude  \
# 36902                 22.0                      5.0             0.000000
# 19951                 30.0                      4.8            21.183434
# 27510                 23.0                      4.6             9.982834
# 31850                 39.0                      4.5            17.438263
# 28331                 39.0                      5.0            17.411028
#
#        Restaurant_longitude  Delivery_location_latitude  \
# 36902              0.000000                    0.070000
# 19951             72.814492                   21.223434
# 27510             76.283268                   10.062834
# 31850             78.397865                   17.518263
# 28331             78.329645                   17.501028
#
#        Delivery_location_longitude Time_Orderd Time_Order_picked  \
# 36902                     0.070000       18:30             18:45
# ...

# %%
cat_cols=df.select_dtypes("object")

# %%
cat_cols=cat_cols.drop(["Time_Orderd","Time_Order_picked"],axis=1)

# %%
for col in cat_cols:
    unique_values = df[col].unique()
    print(f"Unique values in column '{col}': {unique_values}")
# Out:
# Unique values in column 'Weather_conditions': ['Fog' 'Stormy' 'Sandstorms' 'Windy' 'Cloudy' 'Sunny' nan]
# Unique values in column 'Road_traffic_density': ['Jam' 'High' 'Medium' 'Low' nan]
# Unique values in column 'Type_of_order': ['Snack' 'Meal' 'Drinks' 'Buffet']
# Unique values in column 'Type_of_vehicle': ['motorcycle' 'scooter' 'electric_scooter' 'bicycle']
# Unique values in column 'Festival': ['No' 'Yes' nan]
# Unique values in column 'City': ['Metropolitian' 'Urban' 'Semi-Urban' nan]
